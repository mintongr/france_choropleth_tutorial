# %%
# imports 
import plotly as plt
import plotly.express as px
import json
from urllib.request import urlopen 
import pandas as pd

# %%
data = pd.read_csv('patient.csv')
data.head()
# Out:
#     id     sex  birth_year country              region           departement  \
# 0  NaN    male         NaN  France  Nouvelle-Aquitaine     Charente-Maritime
# 1  NaN    male         NaN  France  Nouvelle-Aquitaine               Gironde
# 2  NaN  female         NaN  France  Nouvelle-Aquitaine                Landes
# 3  NaN    male         NaN  France  Nouvelle-Aquitaine  Pyrénées-Atlantiques
# 4  NaN    male         NaN  France  Nouvelle-Aquitaine        Lot-et-Garonne
#
#   city                         group                       infection_reason  \
# 0  NaN                           NaN                   contact with patient
# 1  NaN                           NaN                         visit to Italy
# 2  NaN                           NaN                   contact with patient
# 3  NaN                           NaN                         visit to Italy
# 4  NaN  Mulhouse religious gathering  visit to Mulhouse religious gathering
#
# ...

# %%
regions = data.groupby('region', as_index=False).size()
regions
# Out:
#                      region  size
# 0      Auvergne-Rhône-Alpes   228
# 1   Bourgogne-Franche-Comté   165
# 2                  Bretagne   157
# 3       Centre-Val de Loire    20
# 4                     Corse    63
# 5                 Grand-Est   461
# 6                Guadeloupe     1
# 7                    Guyane     6
# 8           Hauts-de-France    49
# 9             Ile-de-France   440
# 10               La Reunion     5
# 11               Martinique     6
# 12                Normandie    25
# 13       Nouvelle-Aquitaine    87
# 14                Occitanie   118
# 15                     PACA   212
# 16         Pays-de-la-Loire    26
# 17         Saint-Barthélémy     1
# 18             Saint-Martin     2

# %%
with urlopen('https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/france-regions.geojson') as response:
 France = json.load(response)

# %%
for feature in France['features']:
    print(feature['properties'].get('name'))
# Out:
# Alsace
# Lorraine
# Corsica
# Brittany
# Lower Normandy
# Upper Normandy
# Champagne-Ardenne
# Burgundy
# Pays-de-la-Loire
# Limousin
# Midi-Pyrenées
# Franche-Comté
# Provence-Alpes-Cote d'Azur
# Rhone-Alpes
# Picardy
# Aquitaine
# Centre
# Ile-de-France
# Nord-Pas de Calais
# Poitou-Charentes
# Auvergne
# Languedoc-Roussilion

# %%
for feature in France['features']:
    feature['id'] = feature['properties']['name']

# %%
#fig = px.choropleth(regions,geojson=France,locations='region',featureidkey='properties.name',color='size',hover_name='region',
    #color_continuous_scale='algae',title="Coronavirus in France")

#fig.update_geos(fitbounds="locations", visible=False)
#fig.write_html('rainforest_loss_chloropleth.html')
